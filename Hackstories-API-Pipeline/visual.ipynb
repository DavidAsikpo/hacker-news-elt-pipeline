# %%
import pandas as pd
import numpy as np 

data = pd.read_csv("C:\\Projects\\reddit_project\\Reddit-API-Pipeline\\hackstories_posts.csv")
data = pd.DataFrame(data)
data.head()
# Out:
#                                                title  \
# 0  Don't post generated/AI-edited comments. HN is...
# 1                                            Airfoil
# 2                 Open source AI is the path forward
# 3                 My AI skeptic friends are all nuts
# 4            An AI agent published a hit piece on me
#
#                                                  url          author  \
# 0  https://news.ycombinator.com/newsguidelines.ht...    usefulposter
# 1                     https://ciechanow.ski/airfoil/    todsacerdoti
# 2  https://about.fb.com/news/2024/07/open-source-...          atgctg
# 3                https://fly.io/blog/youre-all-nuts/     tabletcorry
# 4  https://theshamblog.com/an-ai-agent-published-...  scottshambaugh
#
#              created_at  points  num_comments
# 0  2026-03-11T19:29:29Z    4229          1668
# 1  2024-02-27T16:32:49Z    2544           296
# 2  2024-07-23T15:08:41Z    2360           887
# ...
